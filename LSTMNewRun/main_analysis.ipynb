# %% [markdown]
# ## -1. Google Collab Set-up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
import os

# 1. Mounting Google Drive: This allows Colab to access files in your Google Drive
drive.mount('/content/drive/')

# 2. Tell Colab where to find your assignment files and where to save your work

# TODO: Enter the relative path in your Google Drive of the assignment.
FOLDERNAME = "CS7643-Final-Project" # e.g. 'cs7643/ps0/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

FULL_PATH = "/content/drive/MyDrive/" + FOLDERNAME
assert os.path.exists(FULL_PATH), "Make sure your FOLDERNAME is correct"
# Out:
# Mounted at /content/drive/

# %%
# %cd $FULL_PATH
# Out:
# /content/drive/MyDrive/CS7643-Final-Project

# %% [markdown]
# *italicized text*
#
# ## 0. Imports

# %%
import os
print("Current directory:", os.getcwd())
print("Files here:", os.listdir())
# Out:
# Current directory: /content/drive/MyDrive/CS7643-Final-Project
# Files here: ['start.py', 'data.pkl', 'README.md', 'RNNmodel.py', 'train.py', 'GARCH_Baseline.ipynb', 'test_data.py', '.git', '__pycache__', 'stock_data.pkl', 'LSTMmodel.py', 'lstm_lookback60_best.pt', 'learning_curves_lookback60.png', 'lstm_lookback60_last.pt', 'main_analysis.ipynb']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from test_data import prepare_data, VolatilityDataset, TICKERS
from LSTMmodel import LSTMModel
from train import run_training, evaluate

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {DEVICE}')
# Out:
# Using device: cpu

# %% [markdown]
# ## 1. Load Data

# %%
returns, target_vol = prepare_data(force_download=False)

print('Returns shape:    ', returns.shape)    # (trading_days, num_stocks)
print('Target vol shape: ', target_vol.shape)
print('Date range:       ', returns.index[0], '→', returns.index[-1])
# Out:
# --- Loading cached data from stock_data.pkl ---
# Returns shape:     (5283, 99)
# Target vol shape:  (5283, 99)
# Date range:        2000-01-03 00:00:00 → 2020-12-30 00:00:00

# %% [markdown]
# ## 2. Chronological Train / Val / Test Splits
#
#
# - **Train:** 2000–2017
# - **Val:** 2018, starting at the 21st trading day (buffer for last training target window)
# - **Test:** 2019–2020, starting at the 21st trading day of 2019

# %%
# --- Slice DataFrames by date ---
train_returns = returns.loc[:'2017-12-31']
train_target  = target_vol.loc[:'2017-12-31']

# Val: all of 2018
val_returns = returns.loc['2018-01-01':'2018-12-31']
val_target  = target_vol.loc['2018-01-01':'2018-12-31']

# Test: 2019–2020 (same reasoning)
test_returns = returns.loc['2019-01-01':'2020-12-31']
test_target  = target_vol.loc['2019-01-01':'2020-12-31']

print(f'Train days: {len(train_returns)}  |  '
      f'Val days: {len(val_returns)}  |  '
      f'Test days: {len(test_returns)}')
# Out:
# Train days: 4528  |  Val days: 251  |  Test days: 504

# %% [markdown]
# ## 3. Build Datasets

# %%
LOOKBACK   = 60   # swap to 10 for the short-lookback experiment
BATCH_SIZE = 256

train_dataset = VolatilityDataset(train_returns, train_target, lookback=LOOKBACK)

train_dataset = VolatilityDataset(train_returns, train_target, lookback=LOOKBACK)
val_dataset   = VolatilityDataset(val_returns,   val_target,   lookback=LOOKBACK)
test_dataset  = VolatilityDataset(test_returns,  test_target,  lookback=LOOKBACK)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

print(f'Train samples: {len(train_dataset):,}')
print(f'Val samples:   {len(val_dataset):,}')
print(f'Test samples:  {len(test_dataset):,}')
# Out:
# Dataset initialized with 402407 valid windows.
# Dataset initialized with 402407 valid windows.
# Dataset initialized with 18718 valid windows.
# Dataset initialized with 41922 valid windows.
# Train samples: 402,407
# Val samples:   18,718
# Test samples:  41,922

# %% [markdown]
# ## 4. Instantiate Model & Optimizer

# %%
NUM_STOCKS  = len(TICKERS)   # 99
EMBED_DIM   = 16
HIDDEN_SIZE = 64
DROPOUT     = 0.15

model = LSTMModel(
    num_stocks=NUM_STOCKS,
    embed_dim=EMBED_DIM,
    hidden_size=64,
    num_layers=2,
    dropout=0.15
).to(DEVICE)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(model)
print(f'\nTrainable parameters: {total_params:,}')

optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3
)
# Out:
# LSTMModel(
#   (stock_embedding): Linear(in_features=99, out_features=16, bias=False)
#   (lstm): LSTM(17, 64, num_layers=2, batch_first=True, dropout=0.15, bidirectional=True)
#   (dropout): Dropout(p=0.15, inplace=False)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )
#
# Trainable parameters: 143,537

# %% [markdown]
# ## 5. Train

# %%
history = run_training(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    device=DEVICE,
    num_epochs=40,
    patience=30,
    checkpoint_path=f'lstm_lookback{LOOKBACK}_best.pt',
    verbose=True,
)
# Out:
# Epoch   1/40 | Train MSE: 0.56911 | Val MSE: 0.17590 | Val MAE: 0.00531 | Val Corr: 0.4181 | LR: 5.00e-04
#   ✓ New best val MSE 0.17590 — model saved.
# Epoch   2/40 | Train MSE: 0.25653 | Val MSE: 0.18639 | Val MAE: 0.00559 | Val Corr: 0.4944 | LR: 5.00e-04
# Epoch   3/40 | Train MSE: 0.20643 | Val MSE: 0.15490 | Val MAE: 0.00491 | Val Corr: 0.5207 | LR: 5.00e-04
#   ✓ New best val MSE 0.15490 — model saved.
# Epoch   4/40 | Train MSE: 0.16405 | Val MSE: 0.13768 | Val MAE: 0.00463 | Val Corr: 0.5727 | LR: 5.00e-04
#   ✓ New best val MSE 0.13768 — model saved.
# Epoch   5/40 | Train MSE: 0.14630 | Val MSE: 0.13361 | Val MAE: 0.00456 | Val Corr: 0.5891 | LR: 5.00e-04
#   ✓ New best val MSE 0.13361 — model saved.
# Epoch   6/40 | Train MSE: 0.13850 | Val MSE: 0.13177 | Val MAE: 0.00446 | Val Corr: 0.6030 | LR: 5.00e-04
#   ✓ New best val MSE 0.13177 — model saved.
# Epoch   7/40 | Train MSE: 0.13036 | Val MSE: 0.14515 | Val MAE: 0.00470 | Val Corr: 0.5660 | LR: 5.00e-04
# Epoch   8/40 | Train MSE: 0.12539 | Val MSE: 0.13712 | Val MAE: 0.00458 | Val Corr: 0.5861 | LR: 5.00e-04
# Epoch   9/40 | Train MSE: 0.12232 | Val MSE: 0.13992 | Val MAE: 0.00465 | Val Corr: 0.5690 | LR: 5.00e-04
# Epoch  10/40 | Train MSE: 0.11881 | Val MSE: 0.13550 | Val MAE: 0.00454 | Val Corr: 0.5917 | LR: 2.50e-04
# Epoch  11/40 | Train MSE: 0.11544 | Val MSE: 0.14120 | Val MAE: 0.00463 | Val Corr: 0.5771 | LR: 2.50e-04
# Epoch  12/40 | Train MSE: 0.11438 | Val MSE: 0.13396 | Val MAE: 0.00455 | Val Corr: 0.5885 | LR: 2.50e-04
# Epoch  13/40 | Train MSE: 0.11295 | Val MSE: 0.13829 | Val MAE: 0.00456 | Val Corr: 0.5930 | LR: 2.50e-04
# Epoch  14/40 | Train MSE: 0.11165 | Val MSE: 0.13848 | Val MAE: 0.00463 | Val Corr: 0.5785 | LR: 1.25e-04
# Epoch  15/40 | Train MSE: 0.11011 | Val MSE: 0.13834 | Val MAE: 0.00457 | Val Corr: 0.5892 | LR: 1.25e-04
# Epoch  16/40 | Train MSE: 0.10929 | Val MSE: 0.13541 | Val MAE: 0.00457 | Val Corr: 0.5866 | LR: 1.25e-04
# Epoch  17/40 | Train MSE: 0.10861 | Val MSE: 0.14051 | Val MAE: 0.00461 | Val Corr: 0.5831 | LR: 1.25e-04
# Epoch  18/40 | Train MSE: 0.10781 | Val MSE: 0.13438 | Val MAE: 0.00455 | Val Corr: 0.5909 | LR: 6.25e-05
# Epoch  19/40 | Train MSE: 0.10669 | Val MSE: 0.13775 | Val MAE: 0.00456 | Val Corr: 0.5890 | LR: 6.25e-05
# Epoch  20/40 | Train MSE: 0.10643 | Val MSE: 0.13544 | Val MAE: 0.00456 | Val Corr: 0.5873 | LR: 6.25e-05
# Epoch  21/40 | Train MSE: 0.10606 | Val MSE: 0.13554 | Val MAE: 0.00454 | Val Corr: 0.5895 | LR: 6.25e-05
# Epoch  22/40 | Train MSE: 0.10567 | Val MSE: 0.13759 | Val MAE: 0.00457 | Val Corr: 0.5885 | LR: 3.13e-05
# Epoch  23/40 | Train MSE: 0.10500 | Val MSE: 0.13940 | Val MAE: 0.00458 | Val Corr: 0.5866 | LR: 3.13e-05
# Epoch  24/40 | Train MSE: 0.10509 | Val MSE: 0.13783 | Val MAE: 0.00458 | Val Corr: 0.5824 | LR: 3.13e-05
# Epoch  25/40 | Train MSE: 0.10452 | Val MSE: 0.13804 | Val MAE: 0.00457 | Val Corr: 0.5861 | LR: 3.13e-05
# Epoch  26/40 | Train MSE: 0.10438 | Val MSE: 0.14034 | Val MAE: 0.00459 | Val Corr: 0.5870 | LR: 1.56e-05
# Epoch  27/40 | Train MSE: 0.10402 | Val MSE: 0.13783 | Val MAE: 0.00458 | Val Corr: 0.5846 | LR: 1.56e-05
# Epoch  28/40 | Train MSE: 0.10410 | Val MSE: 0.13864 | Val MAE: 0.00458 | Val Corr: 0.5856 | LR: 1.56e-05
# Epoch  29/40 | Train MSE: 0.10394 | Val MSE: 0.13910 | Val MAE: 0.00459 | Val Corr: 0.5848 | LR: 1.56e-05
# Epoch  30/40 | Train MSE: 0.10359 | Val MSE: 0.13893 | Val MAE: 0.00458 | Val Corr: 0.5859 | LR: 7.81e-06
# Epoch  31/40 | Train MSE: 0.10365 | Val MSE: 0.13909 | Val MAE: 0.00458 | Val Corr: 0.5841 | LR: 7.81e-06
# Epoch  32/40 | Train MSE: 0.10357 | Val MSE: 0.13905 | Val MAE: 0.00459 | Val Corr: 0.5844 | LR: 7.81e-06
# Epoch  33/40 | Train MSE: 0.10345 | Val MSE: 0.13917 | Val MAE: 0.00458 | Val Corr: 0.5839 | LR: 7.81e-06
# Epoch  34/40 | Train MSE: 0.10354 | Val MSE: 0.13833 | Val MAE: 0.00458 | Val Corr: 0.5838 | LR: 3.91e-06
# Epoch  35/40 | Train MSE: 0.10332 | Val MSE: 0.13922 | Val MAE: 0.00459 | Val Corr: 0.5835 | LR: 3.91e-06
# Epoch  36/40 | Train MSE: 0.10327 | Val MSE: 0.13860 | Val MAE: 0.00458 | Val Corr: 0.5843 | LR: 3.91e-06
#   Early stopping triggered after 36 epochs.
#
# Training complete. Best Val MSE: 0.13177

# %%
torch.save(model.state_dict(), f'lstm_lookback{LOOKBACK}_last.pt')

# %% [markdown]
# ## 6. Learning Curves

# %%
epochs = range(1, len(history['train_mse']) + 1)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(epochs, history['train_mse'], label='Train MSE')
axes[0].plot(epochs, history['val_mse'],   label='Val MSE')
axes[0].set_title('MSE (log-vol space)'); axes[0].legend()

axes[1].plot(epochs, history['val_mae'])
axes[1].set_title('Val MAE (original vol space)')

axes[2].plot(epochs, history['val_corr'])
axes[2].set_title('Val Pearson Correlation')

plt.tight_layout()
plt.savefig(f'learning_curves_lookback{LOOKBACK}.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Test Set Evaluation (full 2019–2020)

# %%
test_metrics = evaluate(model, test_loader, DEVICE)

print('=== Test Results ===')
print(f'  MSE (log-vol):        {test_metrics["mse"]:.5f}')
print(f'  MAE (original vol):   {test_metrics["mae"]:.5f}')
print(f'  Pearson Correlation:  {test_metrics["correlation"]:.4f}')
# Out:
# === Test Results ===
#   MSE (log-vol):        0.23884
#   MAE (original vol):   0.00738
#   Pearson Correlation:  0.5469
